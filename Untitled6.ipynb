# %% [markdown]
# <a href="https://colab.research.google.com/github/Anantkumar5555/deep-Learning/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 10000

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

print("Training samples:", len(x_train))
print("Testing samples:", len(x_test))
# Out:
# Training samples: 25000
# Testing samples: 25000

# %%
max_len = 200

x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

# %%
model = keras.Sequential([
      keras.layers.Embedding(vocab_size, 128, input_length=max_len),
          keras.layers.LSTM(64),
              keras.layers.Dense(1, activation='sigmoid')
              ])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(
      loss='binary_crossentropy',
          optimizer='adam',
              metrics=['accuracy']
              )

# %%
model.fit(x_train, y_train, epochs=3, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 85s 264ms/step - accuracy: 0.7964 - loss: 0.4317 - val_accuracy: 0.8472 - val_loss: 0.3599
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 265ms/step - accuracy: 0.9009 - loss: 0.2558 - val_accuracy: 0.8384 - val_loss: 0.3599
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 82s 261ms/step - accuracy: 0.9247 - loss: 0.1987 - val_accuracy: 0.8592 - val_loss: 0.3782

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8558 - loss: 0.3862
# Test Accuracy: 0.8557999730110168

# %%
# Get word index
word_index = imdb.get_word_index()

# Function to encode text
def encode_text(text):
    tokens = text.lower().split()
    encoded = [word_index.get(word, 2) for word in tokens]  # unknown = 2
    return pad_sequences([encoded], maxlen=max_len)

            # Try your own sentence
sample_text = "this movie was amazing and very good"

encoded = encode_text(sample_text)
prediction = model.predict(encoded)

print("Prediction:", prediction[0][0])

if prediction[0][0] > 0.5:
                print("Positive Review 😊")
else:
                print("Negative Review 😞")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Prediction: 0.6937202
# Positive Review 😊
